# %%
from plotting import animate_simulation, streamlines_and_magnitudes
import matplotlib
# %matplotlib widget
from helpers import load_data, base_path
import gc

# %% [markdown]
# # Lid driven Cavity

# %%
simulation = load_data(base_path + "data/presentation/lidlid_Re4000_512x512_T30000.pkl")
streamlines_and_magnitudes(simulation, colorbar=False, save_params={
    "title": base_path + "data/presentation3/lidlid_Re4000_512x512_T30000",
    "dpi": 600,
}) # type: ignore
del simulation
gc.collect()
# Out:
# Simulation loaded from /home/gandalf/navier-stokes-project/data/presentation/lidlid_Re4000_512x512_T30000.pkl, type: <class 'navier_stokes_GPU2.NavierStokesGPU2'>
# (512, 512) (512, 512) (512, 512)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 58

# %% [markdown]
# # Lid driven Cavity with Box

# %%
simulation = load_data(base_path + "data/presentation/lidlid_box_Re4000_512x512_T30000.pkl")
streamlines_and_magnitudes(simulation, colorbar=False, save_params={
    "title": base_path + "data/presentation3/lidlid_box_Re4000_512x512_T30000",
    "dpi": 600,
}) # type: ignore
del simulation
gc.collect()
# Out:
# Simulation loaded from /home/gandalf/navier-stokes-project/data/presentation/lidlid_box_Re4000_512x512_T30000.pkl, type: <class 'navier_stokes_GPU2.NavierStokesGPU2'>
# (512, 512) (512, 512) (512, 512)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 26

# %% [markdown]
# # Lid driven Cavity with Circle

# %%
simulation = load_data(base_path + "data/presentation/lid_lid_circle_Re4000_512x512_T30000.pkl")
streamlines_and_magnitudes(simulation, colorbar=True, save_params={
    "title": base_path + "data/presentation3/lid_lid_circle_Re4000_512x512_T30000",
    "dpi": 600,
}) # type: ignore
del simulation
gc.collect()
# Out:
# Simulation loaded from /home/gandalf/navier-stokes-project/data/presentation/lid_lid_circle_Re4000_512x512_T30000.pkl, type: <class 'navier_stokes_GPU2.NavierStokesGPU2'>
# (512, 512) (512, 512) (512, 512)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 32

# %% [markdown]
# # Lid driven Cavity with Box - Variable Reynolds Number

# %%
# Re 200
simulation = load_data(base_path + "data/presentation/lidlid_box_Re200_512x512_T10000.pkl")
streamlines_and_magnitudes(simulation, colorbar=False, v_max=2,  save_params={
    "title": base_path + "data/presentation3/lidlid_box_Re200_512x512_T10000",
    "dpi": 600,
}) # type: ignore
del simulation
gc.collect()
# Out:
# Simulation loaded from /home/gandalf/navier-stokes-project/data/presentation/lidlid_box_Re200_512x512_T10000.pkl, type: <class 'navier_stokes_GPU2.NavierStokesGPU2'>
# (512, 512) (512, 512) (512, 512)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 12

# %%
"""# Re 1000
simulation = load_data(base_path + "data/presentation/lidlid_box_Re1000_512x512_T15000.pkl")
streamlines_and_magnitudes(simulation, v_max=2, colorbar=False, save_params={
    "title": base_path + "data/presentation2/lidlid_box_Re1000_512x512_T15000",
    "dpi": 600,
}) # type: ignore
del simulation
gc.collect()"""
# Out:
# '# Re 1000\nsimulation = load_data(base_path + "data/presentation/lidlid_box_Re1000_512x512_T15000.pkl")\nstreamlines_and_magnitudes(simulation, v_max=2, colorbar=False, save_params={\n    "title": base_path + "data/presentation2/lidlid_box_Re1000_512x512_T15000",\n    "dpi": 600,\n}) # type: ignore\ndel simulation\ngc.collect()'

# %%
"""# Re 10000
simulation = load_data(base_path + "data/presentation/lidlid_box_Re10000_512x512_T40000.pkl")
streamlines_and_magnitudes(simulation, v_max=2, colorbar=False, save_params={
    "title": base_path + "data/presentation2/lidlid_box_Re10000_512x512_T40000",
    "dpi": 600,
}) # type: ignore
del simulation
gc.collect()"""
# Out:
# '# Re 10000\nsimulation = load_data(base_path + "data/presentation/lidlid_box_Re10000_512x512_T40000.pkl")\nstreamlines_and_magnitudes(simulation, v_max=2, colorbar=False, save_params={\n    "title": base_path + "data/presentation2/lidlid_box_Re10000_512x512_T40000",\n    "dpi": 600,\n}) # type: ignore\ndel simulation\ngc.collect()'

# %%
"""# Re 10000
simulation = load_data(base_path + "data/presentation/lidlid_box_Re100_512x512_T10000.pkl")
streamlines_and_magnitudes(simulation, v_max=2, colorbar=False, save_params={
    "title": base_path + "data/presentation2/lidlid_box_Re100_512x512_T10000",
    "dpi": 600,
}) # type: ignore
del simulation
gc.collect()"""
# Out:
# '# Re 10000\nsimulation = load_data(base_path + "data/presentation/lidlid_box_Re100_512x512_T10000.pkl")\nstreamlines_and_magnitudes(simulation, v_max=2, colorbar=False, save_params={\n    "title": base_path + "data/presentation2/lidlid_box_Re100_512x512_T10000",\n    "dpi": 600,\n}) # type: ignore\ndel simulation\ngc.collect()'

# %%
# Re 50
simulation = load_data(base_path + "data/presentation/lidlid_box_Re50_512x512_T2000.pkl")
streamlines_and_magnitudes(simulation, v_max=2, colorbar=True, save_params={
    "title": base_path + "data/presentation3/lidlid_box_Re50_512x512_T2000",
    "dpi": 600,
}) # type: ignore
del simulation
gc.collect()
# Out:
# Simulation loaded from /home/gandalf/navier-stokes-project/data/presentation/lidlid_box_Re50_512x512_T2000.pkl, type: <class 'navier_stokes_GPU2.NavierStokesGPU2'>
# (512, 512) (512, 512) (512, 512)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 32

# %% [markdown]
# # Varying T

# %%
# Re 200
simulation = load_data(base_path + "data/presentation/lidlid_box_t_var_Re200_512x512_T10000.pkl")
streamlines_and_magnitudes(simulation, v_max=2, colorbar=False, plot_times=[0.1, 2, 4.5, 6.25], save_params={
    "title": base_path + "data/presentation3/lidlid_box_t_var_Re200_512x512_T10000",
    "dpi": 600,
}) # type: ignore
# animate_simulation(simulation, v_max=2,) # type: ignore
del simulation
gc.collect()
# Out:
# Simulation loaded from /home/gandalf/navier-stokes-project/data/presentation/lidlid_box_t_var_Re200_512x512_T10000.pkl, type: <class 'navier_stokes_GPU2.NavierStokesGPU2'>
# (512, 512) (512, 512) (512, 512)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# (512, 512) (512, 512) (512, 512)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# (512, 512) (512, 512) (512, 512)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# (512, 512) (512, 512) (512, 512)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 12

# %%
"""import matplotlib.pyplot as plt
import numpy as np

f = lambda x: np.sin(2 * np.pi * x *2/10)
plt.clf()
x = np.linspace(0, 10, 1000)
plt.plot(x, f(x))
points = [0.1, 2, 4.5, 6.25] 
plt.scatter(points, f(np.array(points)), color='red')
plt.grid()
plt.show()"""
# Out:
# "import matplotlib.pyplot as plt\nimport numpy as np\n\nf = lambda x: np.sin(2 * np.pi * x *2/10)\nplt.clf()\nx = np.linspace(0, 10, 1000)\nplt.plot(x, f(x))\npoints = [0.1, 2, 4.5, 6.25] \nplt.scatter(points, f(np.array(points)), color='red')\nplt.grid()\nplt.show()"

# %% [markdown]
# # Supplements

# %%
# Re 4000
simulation = load_data(base_path + "data/presentation_addons/voided_channel_box_Re4000_512x512_T10000.pkl")
streamlines_and_magnitudes(simulation, v_max=2, colorbar=True, correct_u=2, save_params={
        "title": base_path + "data/presentation3/voided_channel_t_var_Re4000_120x120_T10000",
    "dpi": 600,
}) # type: ignore
# animate_simulation(simulation, v_max=2,) # type: ignore
del simulation
gc.collect()
# Out:
# Simulation loaded from /home/gandalf/navier-stokes-project/data/presentation_addons/voided_channel_box_Re4000_512x512_T10000.pkl, type: <class 'navier_stokes_GPU2.NavierStokesGPU2'>
# (512, 512) (512, 512) (512, 512)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 9

# %%
# Re 4000
simulation = load_data(base_path + "data/presentation_addons/voided_channel_box_Re4000_512x512_T2000.pkl")
streamlines_and_magnitudes(simulation, v_max=2, plot_times=[2], colorbar=True, correct_u=2, save_params={
        "title": base_path + "data/presentation3/voided_channel_t_var_Re4000_512x512_T2000",
    "dpi": 600,
}) # type: ignore
# animate_simulation(simulation, v_max=2,) # type: ignore
del simulation
gc.collect()
# Out:
# Simulation loaded from /home/gandalf/navier-stokes-project/data/presentation_addons/voided_channel_box_Re4000_512x512_T2000.pkl, type: <class 'navier_stokes_GPU2.NavierStokesGPU2'>
# (512, 512) (512, 512) (512, 512)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 73
