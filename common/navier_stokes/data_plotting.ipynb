# %%
from plotting import animate_simulation, streamlines_and_magnitudes
import matplotlib
# %matplotlib widget
from helpers import load_data, base_path
import gc

# %% [markdown]
# # Lid driven Cavity

# %%
simulation = load_data(base_path + "data/presentation/lidlid_Re4000_512x512_T30000.pkl")
streamlines_and_magnitudes(simulation, save_params={
    "title": base_path + "data/presentation/lidlid_Re4000_512x512_T30000",
    "dpi": 600,
}) # type: ignore
del simulation
gc.collect()
# Out:
# Simulation loaded from /home/gandalf/navier-stokes-project/data/presentation/lidlid_Re4000_512x512_T30000.pkl, type: <class 'navier_stokes_GPU2.NavierStokesGPU2'>
# (512, 512) (512, 512) (512, 512)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 21

# %% [markdown]
# # Lid driven Cavity with Box

# %%
simulation = load_data(base_path + "data/presentation/lidlid_box_Re4000_512x512_T30000.pkl")
streamlines_and_magnitudes(simulation, save_params={
    "title": base_path + "data/presentation/lidlid_box_Re4000_512x512_T30000",
    "dpi": 600,
}) # type: ignore
del simulation
gc.collect()
# Out:
# Simulation loaded from /home/gandalf/navier-stokes-project/data/presentation/lidlid_box_Re4000_512x512_T30000.pkl, type: <class 'navier_stokes_GPU2.NavierStokesGPU2'>
# (512, 512) (512, 512) (512, 512)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 41

# %% [markdown]
# # Lid driven Cavity with Circle

# %% [markdown]
# # Lid driven Cavity with Box - Variable Reynolds Number

# %%
# Re 200
simulation = load_data(base_path + "data/presentation/lidlid_box_Re200_512x512_T10000.pkl")
streamlines_and_magnitudes(simulation, v_max=2,  save_params={
    "title": base_path + "data/presentation/lidlid_box_Re200_512x512_T10000",
    "dpi": 600,
}) # type: ignore
del simulation
gc.collect()
# Out:
# Simulation loaded from /home/gandalf/navier-stokes-project/data/presentation/lidlid_box_Re200_512x512_T10000.pkl, type: <class 'navier_stokes_GPU2.NavierStokesGPU2'>
# (512, 512) (512, 512) (512, 512)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 18

# %%
# Re 1000
simulation = load_data(base_path + "data/presentation/lidlid_box_Re1000_512x512_T15000.pkl")
streamlines_and_magnitudes(simulation, v_max=2, save_params={
    "title": base_path + "data/presentation/lidlid_box_Re1000_512x512_T15000",
    "dpi": 600,
}) # type: ignore
del simulation
gc.collect()
# Out:
# Simulation loaded from /home/gandalf/navier-stokes-project/data/presentation/lidlid_box_Re1000_512x512_T15000.pkl, type: <class 'navier_stokes_GPU2.NavierStokesGPU2'>
# (512, 512) (512, 512) (512, 512)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 30

# %%
# Re 10000
simulation = load_data(base_path + "data/presentation/lidlid_box_Re10000_512x512_T40000.pkl")
streamlines_and_magnitudes(simulation, v_max=2, save_params={
    "title": base_path + "data/presentation/lidlid_box_Re10000_512x512_T40000",
    "dpi": 600,
}) # type: ignore
del simulation
gc.collect()
# Out:
# Simulation loaded from /home/gandalf/navier-stokes-project/data/presentation/lidlid_box_Re10000_512x512_T40000.pkl, type: <class 'navier_stokes_GPU2.NavierStokesGPU2'>
# (512, 512) (512, 512) (512, 512)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 6

# %% [markdown]
# # Varying T

# %%
# Re 4000
simulation = load_data(base_path + "data/presentation/lidlid_box_t_var_Re4000_512x512_T10000.pkl")
streamlines_and_magnitudes(simulation, v_max=2, plot_times=[0.1, 2, 4.5, 6.25], save_params={
    "title": base_path + "data/presentation/lidlid_box_t_var_Re4000_512x512_T10000",
    "dpi": 600,
}) # type: ignore
# animate_simulation(simulation, v_max=2,) # type: ignore
del simulation
gc.collect()
# Out:
# Simulation loaded from /home/gandalf/navier-stokes-project/data/presentation/lidlid_box_t_var_Re4000_512x512_T10000.pkl, type: <class 'navier_stokes_GPU2.NavierStokesGPU2'>
# (512, 512) (512, 512) (512, 512)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# (512, 512) (512, 512) (512, 512)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# (512, 512) (512, 512) (512, 512)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# (512, 512) (512, 512) (512, 512)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 3
